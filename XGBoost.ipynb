# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import math
from sklearn.model_selection import KFold
import xgboost as xgb

# %% [markdown]
# The following code segments are for running the historical analysis shown in figure 2 of the paper. The code does the following:
#
# * Set input path to the data and an output path to where you want to save output data
# * Open data. The data used to run the model can be downloaded from: https://doi.org/10.5518/1152
#
# * Set dependent variable name
# * Set simulation information
# * Set years you would like to analyse
# * Set XGBoost model
# * Loop over simulations and years and fit model to data in each simulation

# %% [markdown]
# Set inpath and outpath

# %%
# Path to the data.
inpath = '.../'

# Outpath where you would like to save output data.
outpath = '.../XGout/'

# %% [markdown]
# Open data

# %%
df = pd.read_pickle(inpath + 'trainvalid.pkl')
df = pd.DataFrame(df)

# %%
df
# Out:
#         FID                                           geometry  \
# 0      6938  POLYGON ((-73.50000 -6.75000, -73.25000 -6.750...
# 1      6939  POLYGON ((-73.50000 -7.00000, -73.25000 -7.000...
# 2      6940  POLYGON ((-73.50000 -7.25000, -73.25000 -7.250...
# 3      6941  POLYGON ((-73.50000 -7.50000, -73.25000 -7.500...
# 4      6942  POLYGON ((-73.50000 -7.75000, -73.25000 -7.750...
# ...     ...                                                ...
# 5126  29463  POLYGON ((-44.75000 -3.00000, -44.50000 -3.000...
# 5127  29657  POLYGON ((-44.50000 -2.50000, -44.25000 -2.500...
# 5128  29658  POLYGON ((-44.50000 -2.75000, -44.25000 -2.750...
# 5129  29659  POLYGON ((-44.50000 -3.00000, -44.25000 -3.000...
# 5130  29853  POLYGON ((-44.25000 -2.50000, -44.00000 -2.500...
#
#                           centre     area_km    states  year  month  \
# 0     POINT (-73.37500 -6.87500)  763.931320  Amazonas  2003      1
# 1     POINT (-73.37500 -7.12500)  763.532945  Amazonas  2003      1
# 2     POINT (-73.37500 -7.37500)  763.120400      Acre  2003      1
# 3     POINT (-73.37500 -7.62500)  762.693690      Acre  2003      1
# 4     POINT (-73.37500 -7.87500)  762.252820      Acre  2003      1
# ...                          ...         ...       ...   ...    ...
# 5126  POINT (-44.62500 -3.12500)  768.202987  Maranhao  2020     12
# 5127  POINT (-44.37500 -2.62500)  768.530736  Maranhao  2020     12
# 5128  POINT (-44.37500 -2.87500)  768.373982  Maranhao  2020     12
# 5129  POINT (-44.37500 -3.12500)  768.202987  Maranhao  2020     12
# 5130  POINT (-44.12500 -2.62500)  768.530736  Maranhao  2020     12
#
#       fire_number     defor  t_month   p_6_month     p_month  pasture_frac  \
# 0             0.0  0.000000  28.2428  713.030685  268.399323         0.000
# 1             0.0  1.357946  28.1812  756.387218  270.729797         0.001
# 2             0.0  8.050515  28.3756  779.980492  248.937378         0.017
# 3             0.0  4.219792  27.8924  805.984306  234.089584         0.005
# 4             0.0  3.456357  27.2764  810.648941  218.884186         0.003
# ...           ...       ...      ...         ...         ...           ...
# 5126          0.0  0.000000  30.4916  333.955908  135.318237         0.050
# 5127          0.0  0.924999  29.5052  351.155690   92.066948         0.043
# 5128          0.0  0.232154  28.4492  366.457522  118.020523         0.053
# 5129          0.0  1.950259  30.0412  328.087385  146.691986         0.255
# 5130          0.0  0.503407  30.6444  325.144393   89.317810         0.089
#
#       crop_frac  savanna_frac  lai_12_month_mean
# 0         0.000         0.000           5.258945
# 1         0.000         0.000           5.231799
# 2         0.000         0.000           5.270495
# 3         0.000         0.000           5.223077
# 4         0.000         0.000           5.252493
# ...         ...           ...                ...
# 5126      0.006         0.487           1.794112
# 5127      0.001         0.008           2.633466
# 5128      0.001         0.085           2.791391
# 5129      0.002         0.200           2.445894
# 5130      0.001         0.002           3.000128
#
# [1108296 rows x 16 columns]

# %% [markdown]
# Print features/variable names. Refer to data README file for a description of variables.

# %%
df.columns
# Out:
# Index(['FID', 'geometry', 'centre', 'area_km', 'states', 'year', 'month',
#        'fire_number', 'defor', 't_month', 'p_6_month', 'p_month',
#        'pasture_frac', 'crop_frac', 'savanna_frac', 'lai_12_month_mean'],
#       dtype='object')

# %% [markdown]
# Set dependent variable name

# %%
dep_var = 'fire_number'

# %% [markdown]
# Resacale featues that we will use in the simultaions.

# %%
df['defor'] = df['defor'] / df['area_km'] 
df['defor'] = (df['defor'] - df['defor'].min())/(df['defor'].max() - df['defor'].min())
df['p_month'] = (df['p_month'] - df['p_month'].min())/(df['p_month'].max() - df['p_month'].min())
df['t_month'] = (df['t_month'] - df['t_month'].min())/(df['t_month'].max() - df['t_month'].min())
df['p_6_month'] = (df['p_6_month'] - df['p_6_month'].min())/(df['p_6_month'].max() - df['p_6_month'].min())
df['lai_12_month_mean'] = (df['lai_12_month_mean'] - df['lai_12_month_mean'].min())/(df['lai_12_month_mean'].max() - df['lai_12_month_mean'].min())

# %% [markdown]
# Set simulation information:
#
# * 'to_drop': features to drop
# * 'sim_label': label used to save predictions for each simulation.
#
# Refer to paper for details about each simulation.

# %%
sim_label = [
    'Sim_Clim+Def',
    'Sim_Clim',
    'Sim_Clim+LU',
    'Sim_Clim+LU+Def'
]

sim_features = [
    
    ['fire_number', 'defor', 't_month', 'p_6_month', 'p_month','lai_12_month_mean', 'year'], # 'Sim_Clim+Def'
    
    ['fire_number', 't_month', 'p_6_month', 'p_month','lai_12_month_mean', 'year'],          # 'Sim_Clim'
    
    ['fire_number', 't_month', 'p_6_month', 'p_month','lai_12_month_mean',                   # 'Sim_Clim+LU'
     'pasture_frac', 'crop_frac', 'savanna_frac', 'year'], 
    
    ['fire_number', 'defor', 't_month', 'p_6_month', 'p_month','lai_12_month_mean',          # 'Sim_Clim+LU+Def'
     'pasture_frac', 'crop_frac', 'savanna_frac', 'year']
    
]

# %% [markdown]
# Set years you would like to analyse. Years allowed 2003 to 2020.

# %%
years = np.arange(2003,2021,1)

# %% [markdown]
# Set Random Forest model and RMSE function

# %%
def xg(X, y,
       objective = 'reg:squarederror',
       n_estimators = 80,
       max_depth = 8,
       learning_rate = 0.1,
       colsample_bytree = 0.8,
       reg_alpha = 1.2,
       reg_lambda = 1.2,
       subsample = 0.9,**kwargs): 
    return xgb.XGBRegressor(objective = objective,
                            n_estimators = n_estimators,
                            max_depth = max_depth,
                            learning_rate = learning_rate,
                            colsample_bytree = colsample_bytree,
                            reg_alpha = reg_alpha,
                            reg_lambda = reg_lambda,
                            subsample = subsample).fit(X, y)

def r_mse(pred,y): 
    return round(math.sqrt(((pred-y)**2).mean()), 6)

# %% [markdown]
# Loop over simulations and years and fit model to data in each simulation

# %%
# Loop through each simulation
for sim_index, sim in enumerate(sim_label):
    # Print simulation
    print(sim)
    
    # Get featues/variables for each simulation
    sim_data = df[sim_features[sim_index]]
       
    # Loop through each year
    for yr in years:
        
        # Print year
        print(yr)
        
        # Copy simulation data
        train = sim_data.copy()
        
        # Get test data. Test set is data for year of interest.
        test = train[(train['year'] == yr)]
        
        # Use this to add test predictions 
        test_original = test.copy()
        
        # Remove test data from train data
        train = train.loc[~((train['year'] == yr)),:]
        
        # Remove 'year' from datasets as it is not needed now
        train = train.drop('year', axis=1)
        test = test.drop('year', axis=1)
        
        # X,y test dataset
        X_test, y_test = test.drop(dep_var,axis=1), test[dep_var]
        
        # Set number of k-folds 
        n_folds = 5 
    
        # Empty array to store test predictions for each k-fold   
        preds_test_ar = np.ones((n_folds,len(X_test)))
        
        # Define splits into k-folds
        kf = KFold(n_splits=n_folds, random_state=42, shuffle=True) 
        kf.get_n_splits(train) # returns the number of splitting iterations in the cross-validator
    
        index_count  = 0
        for train_index, valid_index in kf.split(train):
            index_count += 1
            print(index_count-1)
        
            # Get train and valid set for fold
            X_train, X_valid = train.iloc[train_index], train.iloc[valid_index]
            y_train, y_valid = X_train[dep_var], X_valid[dep_var]  
            
            # Drop dependent/target variable 
            X_train, X_valid = X_train.drop(dep_var,axis=1), X_valid.drop(dep_var,axis=1) 
            
            # Fit model   
            m = xg(X_train,y_train)
            
            # Get fire count predictions for train, valid and test sets
            preds_train = m.predict(X_train)
            preds_valid = m.predict(X_valid)
            preds_test =  m.predict(X_test)

            # Print RMSE for train, valid and test sets
            print('Train RMSE in = ' + str(r_mse(preds_train, y_train)))
            print('Valid RMSE in = ' + str(r_mse(preds_valid, y_valid)))
            print('Test RMSE in ' + str(yr) + '= ' + str(r_mse(preds_test, y_test))) 

            # Store test fire count predictions    
            preds_test_ar[index_count-1,:] = preds_test
        
            # Average and save fire count predictions
            if index_count-1 == 4:  

                # Average test predictions across folds and save 
                test_original['mean_preds'] = np.round(preds_test_ar.mean(axis=0))
                test_original.to_csv(outpath + 'test_preds_'+sim+'_'+str(n_folds)+'folds_'+str(yr)+'.csv', index=False)
# Out:
# Sim_Clim+Def
# 2003
# 0
# Train RMSE in = 5.848876
# Valid RMSE in = 6.953893
# Test RMSE in 2003= 8.318193
# 1
# Train RMSE in = 5.858103
# Valid RMSE in = 7.118663
# Test RMSE in 2003= 8.261812
# 2
# Train RMSE in = 5.826201
# Valid RMSE in = 7.417874
# Test RMSE in 2003= 8.339205
# 3
# Train RMSE in = 5.8695
# Valid RMSE in = 7.157003
# Test RMSE in 2003= 8.282473
# 4
# Train RMSE in = 5.943584
# Valid RMSE in = 6.691726
# Test RMSE in 2003= 8.326632
# 2004
# 0
# Train RMSE in = 5.772994
# Valid RMSE in = 6.848171
# Test RMSE in 2004= 9.76456
# 1
# Train RMSE in = 5.780803
# Valid RMSE in = 6.962302
# Test RMSE in 2004= 9.75958
# 2
# Train RMSE in = 5.758429
# Valid RMSE in = 7.296216
# Test RMSE in 2004= 9.814693
# 3
# Train RMSE in = 5.774158
# Valid RMSE in = 7.092084
# Test RMSE in 2004= 9.668093
# 4
# Train RMSE in = 5.811943
# Valid RMSE in = 6.749953
# Test RMSE in 2004= 9.821328
# 2005
# 0
# Train RMSE in = 5.671123
# Valid RMSE in = 6.726133
# Test RMSE in 2005= 11.450867
# 1
# Train RMSE in = 5.668852
# Valid RMSE in = 6.850099
# Test RMSE in 2005= 11.458358
# 2
# Train RMSE in = 5.603928
# Valid RMSE in = 7.21914
# Test RMSE in 2005= 11.573144
# 3
# Train RMSE in = 5.685494
# Valid RMSE in = 6.874792
# Test RMSE in 2005= 11.469449
# 4
# Train RMSE in = 5.70111
# Valid RMSE in = 6.563039
# Test RMSE in 2005= 11.462679
# 2006
# 0
# Train RMSE in = 5.939786
# Valid RMSE in = 7.119146
# Test RMSE in 2006= 7.503367
# 1
# Train RMSE in = 5.923781
# Valid RMSE in = 7.203269
# Test RMSE in 2006= 7.450747
# 2
# Train RMSE in = 5.906324
# Valid RMSE in = 7.356583
# Test RMSE in 2006= 7.492599
# 3
# Train RMSE in = 5.953124
# Valid RMSE in = 7.212864
# Test RMSE in 2006= 7.472313
# 4
# Train RMSE in = 5.968086
# Valid RMSE in = 6.822494
# Test RMSE in 2006= 7.491282
# 2007
# 0
# Train RMSE in = 5.690568
# Valid RMSE in = 6.84423
# Test RMSE in 2007= 11.813054
# 1
# Train RMSE in = 5.672249
# Valid RMSE in = 6.946984
# Test RMSE in 2007= 11.837236
# 2
# Train RMSE in = 5.673172
# Valid RMSE in = 6.941102
# Test RMSE in 2007= 11.726451
# 3
# Train RMSE in = 5.711878
# Valid RMSE in = 6.934439
# Test RMSE in 2007= 11.798515
# 4
# Train RMSE in = 5.733649
# Valid RMSE in = 6.545695
# Test RMSE in 2007= 11.672945
# 2008
# 0
# Train RMSE in = 5.911269
# Valid RMSE in = 7.262243
# Test RMSE in 2008= 6.230751
# 1
# Train RMSE in = 6.008093
# Valid RMSE in = 7.338413
# Test RMSE in 2008= 6.23148
# 2
# Train RMSE in = 5.95142
# Valid RMSE in = 7.248094
# Test RMSE in 2008= 6.159216
# 3
# Train RMSE in = 5.987421
# Valid RMSE in = 7.310401
# Test RMSE in 2008= 6.218274
# 4
# Train RMSE in = 5.985789
# Valid RMSE in = 6.961805
# Test RMSE in 2008= 6.307158
# 2009
# 0
# Train RMSE in = 6.00303
# Valid RMSE in = 7.276939
# Test RMSE in 2009= 5.085344
# 1
# Train RMSE in = 6.057223
# Valid RMSE in = 7.362975
# Test RMSE in 2009= 5.07668
# 2
# Train RMSE in = 6.059361
# Valid RMSE in = 7.314008
# Test RMSE in 2009= 5.173819
# 3
# Train RMSE in = 6.07609
# Valid RMSE in = 7.35191
# Test RMSE in 2009= 5.120544
# 4
# Train RMSE in = 6.071631
# Valid RMSE in = 7.023768
# Test RMSE in 2009= 5.1749
# 2010
# 0
# Train RMSE in = 5.699517
# Valid RMSE in = 6.846893
# Test RMSE in 2010= 12.056257
# 1
# Train RMSE in = 5.754543
# Valid RMSE in = 6.731377
# Test RMSE in 2010= 12.042648
# 2
# Train RMSE in = 5.718955
# Valid RMSE in = 6.710945
# Test RMSE in 2010= 12.109728
# 3
# Train RMSE in = 5.681104
# Valid RMSE in = 6.890982
# Test RMSE in 2010= 12.111813
# 4
# Train RMSE in = 5.661908
# Valid RMSE in = 6.763652
# Test RMSE in 2010= 12.119914
# 2011
# 0
# Train RMSE in = 6.100626
# Valid RMSE in = 7.214539
# Test RMSE in 2011= 3.493007
# 1
# Train RMSE in = 6.124653
# Valid RMSE in = 7.347846
# Test RMSE in 2011= 3.520056
# 2
# Train RMSE in = 6.068125
# Valid RMSE in = 7.378712
# Test RMSE in 2011= 3.522189
# 3
# Train RMSE in = 6.097126
# Valid RMSE in = 7.221789
# Test RMSE in 2011= 3.512885
# 4
# Train RMSE in = 6.114336
# Valid RMSE in = 7.425123
# Test RMSE in 2011= 3.526778
# 2012
# 0
# Train RMSE in = 6.026666
# Valid RMSE in = 7.217968
# Test RMSE in 2012= 5.08611
# 1
# Train RMSE in = 6.046299
# Valid RMSE in = 7.267829
# Test RMSE in 2012= 5.141681
# 2
# Train RMSE in = 6.042714
# Valid RMSE in = 7.287095
# Test RMSE in 2012= 5.136999
# 3
# Train RMSE in = 6.052543
# Valid RMSE in = 7.198383
# Test RMSE in 2012= 5.136718
# 4
# Train RMSE in = 6.004506
# Valid RMSE in = 7.341818
# Test RMSE in 2012= 5.150265
# 2013
# 0
# Train RMSE in = 6.07549
# Valid RMSE in = 7.266349
# Test RMSE in 2013= 2.81297
# 1
# Train RMSE in = 6.124245
# Valid RMSE in = 7.331074
# Test RMSE in 2013= 2.862601
# 2
# Train RMSE in = 6.15449
# Valid RMSE in = 7.375937
# Test RMSE in 2013= 2.814286
# 3
# Train RMSE in = 6.138283
# Valid RMSE in = 7.247514
# Test RMSE in 2013= 2.843241
# 4
# Train RMSE in = 6.11985
# Valid RMSE in = 7.431974
# Test RMSE in 2013= 2.83014
# 2014
# 0
# Train RMSE in = 6.063314
# Valid RMSE in = 7.229902
# Test RMSE in 2014= 4.297498
# 1
# Train RMSE in = 6.097923
# Valid RMSE in = 7.289445
# Test RMSE in 2014= 4.334739
# 2
# Train RMSE in = 6.053215
# Valid RMSE in = 7.387994
# Test RMSE in 2014= 4.328854
# 3
# Train RMSE in = 6.043711
# Valid RMSE in = 7.201828
# Test RMSE in 2014= 4.296328
# 4
# Train RMSE in = 6.07984
# Valid RMSE in = 7.405753
# Test RMSE in 2014= 4.335323
# 2015
# 0
# Train RMSE in = 5.980172
# Valid RMSE in = 7.162973
# Test RMSE in 2015= 5.900961
# 1
# Train RMSE in = 6.031027
# Valid RMSE in = 7.232778
# Test RMSE in 2015= 5.87596
# 2
# Train RMSE in = 5.964822
# Valid RMSE in = 7.280367
# Test RMSE in 2015= 5.933648
# 3
# Train RMSE in = 6.003485
# Valid RMSE in = 7.148156
# Test RMSE in 2015= 5.89608
# 4
# Train RMSE in = 6.00435
# Valid RMSE in = 7.328664
# Test RMSE in 2015= 5.868332
# 2016
# 0
# Train RMSE in = 5.991679
# Valid RMSE in = 7.146788
# Test RMSE in 2016= 5.910953
# 1
# Train RMSE in = 6.007962
# Valid RMSE in = 7.254665
# Test RMSE in 2016= 6.157044
# 2
# Train RMSE in = 5.992375
# Valid RMSE in = 7.32686
# Test RMSE in 2016= 5.819223
# 3
# Train RMSE in = 6.014279
# Valid RMSE in = 7.123523
# Test RMSE in 2016= 6.035895
# 4
# Train RMSE in = 5.997521
# Valid RMSE in = 7.322449
# Test RMSE in 2016= 5.726705
# 2017
# 0
# Train RMSE in = 5.959758
# Valid RMSE in = 7.064274
# Test RMSE in 2017= 6.502296
# 1
# Train RMSE in = 5.99101
# Valid RMSE in = 7.246258
# Test RMSE in 2017= 6.627677
# 2
# Train RMSE in = 5.967725
# Valid RMSE in = 7.273354
# Test RMSE in 2017= 6.638797
# 3
# Train RMSE in = 5.960026
# Valid RMSE in = 7.133835
# Test RMSE in 2017= 6.641876
# 4
# Train RMSE in = 5.965707
# Valid RMSE in = 7.314613
# Test RMSE in 2017= 6.52508
# 2018
# 0
# Train RMSE in = 6.053504
# Valid RMSE in = 7.188827
# Test RMSE in 2018= 4.150361
# 1
# Train RMSE in = 6.064907
# Valid RMSE in = 7.360241
# Test RMSE in 2018= 4.150432
# 2
# Train RMSE in = 6.045457
# Valid RMSE in = 7.299828
# Test RMSE in 2018= 4.122418
# 3
# Train RMSE in = 6.062637
# Valid RMSE in = 7.240591
# Test RMSE in 2018= 4.150265
# 4
# Train RMSE in = 6.083766
# Valid RMSE in = 7.382452
# Test RMSE in 2018= 4.08687
# 2019
# 0
# Train RMSE in = 5.927451
# Valid RMSE in = 6.995927
# Test RMSE in 2019= 7.221939
# 1
# Train RMSE in = 5.955894
# Valid RMSE in = 7.222167
# Test RMSE in 2019= 7.244066
# 2
# Train RMSE in = 5.918393
# Valid RMSE in = 7.187921
# Test RMSE in 2019= 7.2131
# 3
# Train RMSE in = 5.921038
# Valid RMSE in = 7.14732
# Test RMSE in 2019= 7.199304
# 4
# Train RMSE in = 5.931083
# Valid RMSE in = 7.307615
# Test RMSE in 2019= 7.130197
# 2020
# 0
# Train RMSE in = 5.935253
# Valid RMSE in = 7.022972
# Test RMSE in 2020= 6.741703
# 1
# Train RMSE in = 6.007645
# Valid RMSE in = 7.248855
# Test RMSE in 2020= 6.552828
# 2
# Train RMSE in = 5.903438
# Valid RMSE in = 7.264313
# Test RMSE in 2020= 6.644993
# 3
# Train RMSE in = 5.926989
# Valid RMSE in = 7.130986
# Test RMSE in 2020= 6.60421
# 4
# Train RMSE in = 5.960685
# Valid RMSE in = 7.368955
# Test RMSE in 2020= 6.527312
# Sim_Clim
# 2003
# 0
# Train RMSE in = 7.698372
# Valid RMSE in = 8.291806
# Test RMSE in 2003= 9.892844
# 1
# Train RMSE in = 7.688807
# Valid RMSE in = 8.50304
# Test RMSE in 2003= 9.904959
# 2
# Train RMSE in = 7.635176
# Valid RMSE in = 8.969379
# Test RMSE in 2003= 9.881842
# 3
# Train RMSE in = 7.647359
# Valid RMSE in = 8.7247
# Test RMSE in 2003= 9.892205
# 4
# Train RMSE in = 7.795998
# Valid RMSE in = 8.056833
# Test RMSE in 2003= 9.880654
# 2004
# 0
# Train RMSE in = 7.525363
# Valid RMSE in = 8.096799
# Test RMSE in 2004= 12.533617
# 1
# Train RMSE in = 7.51764
# Valid RMSE in = 8.221471
# Test RMSE in 2004= 12.548813
# 2
# Train RMSE in = 7.443852
# Valid RMSE in = 8.701368
# Test RMSE in 2004= 12.554497
# 3
# Train RMSE in = 7.48296
# Valid RMSE in = 8.592469
# Test RMSE in 2004= 12.517796
# 4
# Train RMSE in = 7.549873
# Valid RMSE in = 7.990792
# Test RMSE in 2004= 12.538188
# 2005
# 0
# Train RMSE in = 7.375672
# Valid RMSE in = 7.864732
# Test RMSE in 2005= 14.937475
# 1
# Train RMSE in = 7.322169
# Valid RMSE in = 8.049472
# Test RMSE in 2005= 14.931243
# 2
# Train RMSE in = 7.235874
# Valid RMSE in = 8.542793
# Test RMSE in 2005= 14.972069
# 3
# Train RMSE in = 7.300221
# Valid RMSE in = 8.194563
# Test RMSE in 2005= 14.931335
# 4
# Train RMSE in = 7.372075
# Valid RMSE in = 7.754598
# Test RMSE in 2005= 14.924072
# 2006
# 0
# Train RMSE in = 7.799874
# Valid RMSE in = 8.411769
# Test RMSE in 2006= 9.351006
# 1
# Train RMSE in = 7.780497
# Valid RMSE in = 8.582175
# Test RMSE in 2006= 9.335994
# 2
# Train RMSE in = 7.702227
# Valid RMSE in = 8.867372
# Test RMSE in 2006= 9.362985
# 3
# Train RMSE in = 7.745573
# Valid RMSE in = 8.69107
# Test RMSE in 2006= 9.320088
# 4
# Train RMSE in = 7.807772
# Valid RMSE in = 8.16372
# Test RMSE in 2006= 9.357823
# 2007
# 0
# Train RMSE in = 7.468057
# Valid RMSE in = 8.172348
# Test RMSE in 2007= 13.769175
# 1
# Train RMSE in = 7.492281
# Valid RMSE in = 8.277723
# Test RMSE in 2007= 13.761447
# 2
# Train RMSE in = 7.467524
# Valid RMSE in = 8.360759
# Test RMSE in 2007= 13.771449
# 3
# Train RMSE in = 7.506336
# Valid RMSE in = 8.328562
# Test RMSE in 2007= 13.765693
# 4
# Train RMSE in = 7.508759
# Valid RMSE in = 7.954798
# Test RMSE in 2007= 13.745031
# 2008
# 0
# Train RMSE in = 7.901447
# Valid RMSE in = 8.701732
# Test RMSE in 2008= 6.524327
# 1
# Train RMSE in = 7.897075
# Valid RMSE in = 8.820517
# Test RMSE in 2008= 6.539825
# 2
# Train RMSE in = 7.874618
# Valid RMSE in = 8.726225
# Test RMSE in 2008= 6.561813
# 3
# Train RMSE in = 7.885189
# Valid RMSE in = 8.807216
# Test RMSE in 2008= 6.564612
# 4
# Train RMSE in = 7.938759
# Valid RMSE in = 8.461054
# Test RMSE in 2008= 6.531781
# 2009
# 0
# Train RMSE in = 7.992601
# Valid RMSE in = 8.789786
# Test RMSE in 2009= 4.918888
# 1
# Train RMSE in = 7.975307
# Valid RMSE in = 8.847124
# Test RMSE in 2009= 4.908068
# 2
# Train RMSE in = 7.947987
# Valid RMSE in = 8.815279
# Test RMSE in 2009= 4.896566
# 3
# Train RMSE in = 7.966844
# Valid RMSE in = 8.872865
# Test RMSE in 2009= 4.924463
# 4
# Train RMSE in = 8.021135
# Valid RMSE in = 8.50169
# Test RMSE in 2009= 4.913552
# 2010
# 0
# Train RMSE in = 7.573006
# Valid RMSE in = 8.352514
# Test RMSE in 2010= 12.595649
# 1
# Train RMSE in = 7.628343
# Valid RMSE in = 8.255525
# Test RMSE in 2010= 12.561291
# 2
# Train RMSE in = 7.603969
# Valid RMSE in = 8.305378
# Test RMSE in 2010= 12.633051
# 3
# Train RMSE in = 7.623686
# Valid RMSE in = 8.364438
# Test RMSE in 2010= 12.601149
# 4
# Train RMSE in = 7.596868
# Valid RMSE in = 8.276409
# Test RMSE in 2010= 12.566977
# 2011
# 0
# Train RMSE in = 7.990032
# Valid RMSE in = 8.713578
# Test RMSE in 2011= 4.423172
# 1
# Train RMSE in = 7.989207
# Valid RMSE in = 8.804023
# Test RMSE in 2011= 4.477639
# 2
# Train RMSE in = 7.984137
# Valid RMSE in = 8.854685
# Test RMSE in 2011= 4.486241
# 3
# Train RMSE in = 7.948133
# Valid RMSE in = 8.702252
# Test RMSE in 2011= 4.472757
# 4
# Train RMSE in = 7.974385
# Valid RMSE in = 8.828046
# Test RMSE in 2011= 4.494101
# 2012
# 0
# Train RMSE in = 7.913955
# Valid RMSE in = 8.692056
# Test RMSE in 2012= 6.101541
# 1
# Train RMSE in = 7.938633
# Valid RMSE in = 8.737313
# Test RMSE in 2012= 6.109808
# 2
# Train RMSE in = 7.905325
# Valid RMSE in = 8.771081
# Test RMSE in 2012= 6.090927
# 3
# Train RMSE in = 7.954772
# Valid RMSE in = 8.646936
# Test RMSE in 2012= 6.119431
# 4
# Train RMSE in = 7.932365
# Valid RMSE in = 8.748349
# Test RMSE in 2012= 6.124593
# 2013
# 0
# Train RMSE in = 8.012532
# Valid RMSE in = 8.763326
# Test RMSE in 2013= 3.439125
# 1
# Train RMSE in = 8.027168
# Valid RMSE in = 8.823694
# Test RMSE in 2013= 3.443008
# 2
# Train RMSE in = 8.002929
# Valid RMSE in = 8.874065
# Test RMSE in 2013= 3.441872
# 3
# Train RMSE in = 8.056861
# Valid RMSE in = 8.756632
# Test RMSE in 2013= 3.431067
# 4
# Train RMSE in = 8.001206
# Valid RMSE in = 8.828002
# Test RMSE in 2013= 3.428921
# 2014
# 0
# Train RMSE in = 7.961164
# Valid RMSE in = 8.703617
# Test RMSE in 2014= 5.11876
# 1
# Train RMSE in = 8.014601
# Valid RMSE in = 8.777361
# Test RMSE in 2014= 5.122145
# 2
# Train RMSE in = 7.935151
# Valid RMSE in = 8.846955
# Test RMSE in 2014= 5.152201
# 3
# Train RMSE in = 7.953332
# Valid RMSE in = 8.668161
# Test RMSE in 2014= 5.137941
# 4
# Train RMSE in = 7.953784
# Valid RMSE in = 8.802067
# Test RMSE in 2014= 5.12975
# 2015
# 0
# Train RMSE in = 7.857712
# Valid RMSE in = 8.572724
# Test RMSE in 2015= 7.481888
# 1
# Train RMSE in = 7.849939
# Valid RMSE in = 8.692479
# Test RMSE in 2015= 7.457381
# 2
# Train RMSE in = 7.842035
# Valid RMSE in = 8.74569
# Test RMSE in 2015= 7.455341
# 3
# Train RMSE in = 7.85165
# Valid RMSE in = 8.592358
# Test RMSE in 2015= 7.485883
# 4
# Train RMSE in = 7.830552
# Valid RMSE in = 8.705173
# Test RMSE in 2015= 7.491162
# 2016
# 0
# Train RMSE in = 7.882431
# Valid RMSE in = 8.591427
# Test RMSE in 2016= 7.442306
# 1
# Train RMSE in = 7.866019
# Valid RMSE in = 8.727479
# Test RMSE in 2016= 7.56676
# 2
# Train RMSE in = 7.894381
# Valid RMSE in = 8.803256
# Test RMSE in 2016= 7.370017
# 3
# Train RMSE in = 7.871667
# Valid RMSE in = 8.58866
# Test RMSE in 2016= 7.275034
# 4
# Train RMSE in = 7.879348
# Valid RMSE in = 8.704081
# Test RMSE in 2016= 7.269105
# 2017
# 0
# Train RMSE in = 7.918981
# Valid RMSE in = 8.565269
# Test RMSE in 2017= 7.2721
# 1
# Train RMSE in = 7.837266
# Valid RMSE in = 8.771168
# Test RMSE in 2017= 7.285549
# 2
# Train RMSE in = 7.855567
# Valid RMSE in = 8.756819
# Test RMSE in 2017= 7.31807
# 3
# Train RMSE in = 7.907726
# Valid RMSE in = 8.625649
# Test RMSE in 2017= 7.265085
# 4
# Train RMSE in = 7.898182
# Valid RMSE in = 8.690069
# Test RMSE in 2017= 7.217569
# 2018
# 0
# Train RMSE in = 7.978737
# Valid RMSE in = 8.631573
# Test RMSE in 2018= 5.134667
# 1
# Train RMSE in = 7.941197
# Valid RMSE in = 8.832656
# Test RMSE in 2018= 5.128828
# 2
# Train RMSE in = 7.90999
# Valid RMSE in = 8.827347
# Test RMSE in 2018= 5.112816
# 3
# Train RMSE in = 7.969325
# Valid RMSE in = 8.699365
# Test RMSE in 2018= 5.157246
# 4
# Train RMSE in = 7.971502
# Valid RMSE in = 8.774245
# Test RMSE in 2018= 5.118545
# 2019
# 0
# Train RMSE in = 7.86325
# Valid RMSE in = 8.480768
# Test RMSE in 2019= 8.348283
# 1
# Train RMSE in = 7.808009
# Valid RMSE in = 8.691423
# Test RMSE in 2019= 8.34888
# 2
# Train RMSE in = 7.804697
# Valid RMSE in = 8.697503
# Test RMSE in 2019= 8.293266
# 3
# Train RMSE in = 7.810423
# Valid RMSE in = 8.574426
# Test RMSE in 2019= 8.332191
# 4
# Train RMSE in = 7.825911
# Valid RMSE in = 8.646452
# Test RMSE in 2019= 8.343959
# 2020
# 0
# Train RMSE in = 7.835272
# Valid RMSE in = 8.501839
# Test RMSE in 2020= 7.435272
# 1
# Train RMSE in = 7.858788
# Valid RMSE in = 8.74962
# Test RMSE in 2020= 7.48273
# 2
# Train RMSE in = 7.842956
# Valid RMSE in = 8.807045
# Test RMSE in 2020= 7.539781
# 3
# Train RMSE in = 7.872882
# Valid RMSE in = 8.569471
# Test RMSE in 2020= 7.456172
# 4
# Train RMSE in = 7.827189
# Valid RMSE in = 8.702963
# Test RMSE in 2020= 7.474959
# Sim_Clim+LU
# 2003
# 0
# Train RMSE in = 7.003271
# Valid RMSE in = 7.652826
# Test RMSE in 2003= 9.192841
# 1
# Train RMSE in = 6.933751
# Valid RMSE in = 7.933447
# Test RMSE in 2003= 9.221692
# 2
# Train RMSE in = 6.886126
# Valid RMSE in = 8.336118
# Test RMSE in 2003= 9.225956
# 3
# Train RMSE in = 6.946106
# Valid RMSE in = 8.0724
# Test RMSE in 2003= 9.258638
# 4
# Train RMSE in = 7.01528
# Valid RMSE in = 7.396794
# Test RMSE in 2003= 9.228536
# 2004
# 0
# Train RMSE in = 6.82856
# Valid RMSE in = 7.467365
# Test RMSE in 2004= 11.804376
# 1
# Train RMSE in = 6.72349
# Valid RMSE in = 7.664284
# Test RMSE in 2004= 11.801028
# 2
# Train RMSE in = 6.683355
# Valid RMSE in = 8.086943
# Test RMSE in 2004= 11.819172
# 3
# Train RMSE in = 6.720808
# Valid RMSE in = 7.895168
# Test RMSE in 2004= 11.804948
# 4
# Train RMSE in = 6.842898
# Valid RMSE in = 7.339828
# Test RMSE in 2004= 11.80608
# 2005
# 0
# Train RMSE in = 6.664833
# Valid RMSE in = 7.217403
# Test RMSE in 2005= 14.000576
# 1
# Train RMSE in = 6.613383
# Valid RMSE in = 7.524307
# Test RMSE in 2005= 13.942409
# 2
# Train RMSE in = 6.47964
# Valid RMSE in = 7.924105
# Test RMSE in 2005= 14.065402
# 3
# Train RMSE in = 6.575127
# Valid RMSE in = 7.573053
# Test RMSE in 2005= 13.969781
# 4
# Train RMSE in = 6.684087
# Valid RMSE in = 7.138475
# Test RMSE in 2005= 13.97995
# 2006
# 0
# Train RMSE in = 7.026583
# Valid RMSE in = 7.813932
# Test RMSE in 2006= 8.643416
# 1
# Train RMSE in = 7.00258
# Valid RMSE in = 8.022622
# Test RMSE in 2006= 8.583978
# 2
# Train RMSE in = 6.948898
# Valid RMSE in = 8.234876
# Test RMSE in 2006= 8.649029
# 3
# Train RMSE in = 7.022992
# Valid RMSE in = 8.042018
# Test RMSE in 2006= 8.587929
# 4
# Train RMSE in = 7.095831
# Valid RMSE in = 7.530732
# Test RMSE in 2006= 8.609744
# 2007
# 0
# Train RMSE in = 6.79775
# Valid RMSE in = 7.583897
# Test RMSE in 2007= 12.704645
# 1
# Train RMSE in = 6.775205
# Valid RMSE in = 7.761565
# Test RMSE in 2007= 12.638924
# 2
# Train RMSE in = 6.742007
# Valid RMSE in = 7.769347
# Test RMSE in 2007= 12.647398
# 3
# Train RMSE in = 6.784198
# Valid RMSE in = 7.715252
# Test RMSE in 2007= 12.654281
# 4
# Train RMSE in = 6.840831
# Valid RMSE in = 7.389335
# Test RMSE in 2007= 12.66935
# 2008
# 0
# Train RMSE in = 7.133193
# Valid RMSE in = 8.046138
# Test RMSE in 2008= 6.253047
# 1
# Train RMSE in = 7.132366
# Valid RMSE in = 8.258055
# Test RMSE in 2008= 6.168273
# 2
# Train RMSE in = 7.149823
# Valid RMSE in = 8.096376
# Test RMSE in 2008= 6.159584
# 3
# Train RMSE in = 7.113583
# Valid RMSE in = 8.12848
# Test RMSE in 2008= 6.165801
# 4
# Train RMSE in = 7.146932
# Valid RMSE in = 7.805775
# Test RMSE in 2008= 6.158322
# 2009
# 0
# Train RMSE in = 7.217844
# Valid RMSE in = 8.101113
# Test RMSE in 2009= 4.61523
# 1
# Train RMSE in = 7.179877
# Valid RMSE in = 8.278141
# Test RMSE in 2009= 4.64862
# 2
# Train RMSE in = 7.168793
# Valid RMSE in = 8.16067
# Test RMSE in 2009= 4.584654
# 3
# Train RMSE in = 7.178417
# Valid RMSE in = 8.191642
# Test RMSE in 2009= 4.612776
# 4
# Train RMSE in = 7.233623
# Valid RMSE in = 7.838278
# Test RMSE in 2009= 4.602197
# 2010
# 0
# Train RMSE in = 6.903929
# Valid RMSE in = 7.744757
# Test RMSE in 2010= 11.741655
# 1
# Train RMSE in = 6.924628
# Valid RMSE in = 7.710687
# Test RMSE in 2010= 11.790152
# 2
# Train RMSE in = 6.894599
# Valid RMSE in = 7.673285
# Test RMSE in 2010= 11.818572
# 3
# Train RMSE in = 6.887677
# Valid RMSE in = 7.769162
# Test RMSE in 2010= 11.794719
# 4
# Train RMSE in = 6.926105
# Valid RMSE in = 7.636386
# Test RMSE in 2010= 11.81229
# 2011
# 0
# Train RMSE in = 7.166964
# Valid RMSE in = 8.032088
# Test RMSE in 2011= 5.013861
# 1
# Train RMSE in = 7.179902
# Valid RMSE in = 8.187461
# Test RMSE in 2011= 5.031854
# 2
# Train RMSE in = 7.165195
# Valid RMSE in = 8.155948
# Test RMSE in 2011= 4.930514
# 3
# Train RMSE in = 7.191336
# Valid RMSE in = 8.003828
# Test RMSE in 2011= 4.956769
# 4
# Train RMSE in = 7.160335
# Valid RMSE in = 8.130732
# Test RMSE in 2011= 4.943962
# 2012
# 0
# Train RMSE in = 7.111761
# Valid RMSE in = 8.011729
# Test RMSE in 2012= 6.083391
# 1
# Train RMSE in = 7.120365
# Valid RMSE in = 8.15053
# Test RMSE in 2012= 6.207082
# 2
# Train RMSE in = 7.119067
# Valid RMSE in = 8.078473
# Test RMSE in 2012= 6.108189
# 3
# Train RMSE in = 7.130969
# Valid RMSE in = 7.959894
# Test RMSE in 2012= 6.080209
# 4
# Train RMSE in = 7.175209
# Valid RMSE in = 8.043718
# Test RMSE in 2012= 6.057633
# 2013
# 0
# Train RMSE in = 7.247541
# Valid RMSE in = 8.069388
# Test RMSE in 2013= 3.498211
# 1
# Train RMSE in = 7.237342
# Valid RMSE in = 8.246138
# Test RMSE in 2013= 3.599136
# 2
# Train RMSE in = 7.219817
# Valid RMSE in = 8.197158
# Test RMSE in 2013= 3.531339
# 3
# Train RMSE in = 7.254977
# Valid RMSE in = 8.061846
# Test RMSE in 2013= 3.515921
# 4
# Train RMSE in = 7.245181
# Valid RMSE in = 8.181904
# Test RMSE in 2013= 3.534427
# 2014
# 0
# Train RMSE in = 7.205831
# Valid RMSE in = 8.025733
# Test RMSE in 2014= 4.860513
# 1
# Train RMSE in = 7.205982
# Valid RMSE in = 8.190825
# Test RMSE in 2014= 4.840431
# 2
# Train RMSE in = 7.188977
# Valid RMSE in = 8.186903
# Test RMSE in 2014= 4.864095
# 3
# Train RMSE in = 7.231057
# Valid RMSE in = 8.003355
# Test RMSE in 2014= 4.820044
# 4
# Train RMSE in = 7.189598
# Valid RMSE in = 8.145711
# Test RMSE in 2014= 4.813359
# 2015
# 0
# Train RMSE in = 7.072786
# Valid RMSE in = 7.958512
# Test RMSE in 2015= 6.862628
# 1
# Train RMSE in = 7.085847
# Valid RMSE in = 8.105373
# Test RMSE in 2015= 6.882093
# 2
# Train RMSE in = 7.077788
# Valid RMSE in = 8.083638
# Test RMSE in 2015= 6.851149
# 3
# Train RMSE in = 7.101261
# Valid RMSE in = 7.915861
# Test RMSE in 2015= 6.895232
# 4
# Train RMSE in = 7.090709
# Valid RMSE in = 8.058376
# Test RMSE in 2015= 6.877387
# 2016
# 0
# Train RMSE in = 7.109363
# Valid RMSE in = 7.966216
# Test RMSE in 2016= 6.748004
# 1
# Train RMSE in = 7.094787
# Valid RMSE in = 8.117385
# Test RMSE in 2016= 6.833699
# 2
# Train RMSE in = 7.078429
# Valid RMSE in = 8.12717
# Test RMSE in 2016= 6.680712
# 3
# Train RMSE in = 7.132696
# Valid RMSE in = 7.905325
# Test RMSE in 2016= 6.677087
# 4
# Train RMSE in = 7.130661
# Valid RMSE in = 8.070459
# Test RMSE in 2016= 6.57486
# 2017
# 0
# Train RMSE in = 7.128014
# Valid RMSE in = 7.905241
# Test RMSE in 2017= 6.67717
# 1
# Train RMSE in = 7.110405
# Valid RMSE in = 8.176018
# Test RMSE in 2017= 6.690936
# 2
# Train RMSE in = 7.080736
# Valid RMSE in = 8.109056
# Test RMSE in 2017= 6.655324
# 3
# Train RMSE in = 7.145938
# Valid RMSE in = 7.966235
# Test RMSE in 2017= 6.669748
# 4
# Train RMSE in = 7.106986
# Valid RMSE in = 8.068729
# Test RMSE in 2017= 6.641582
# 2018
# 0
# Train RMSE in = 7.189599
# Valid RMSE in = 8.000267
# Test RMSE in 2018= 4.533501
# 1
# Train RMSE in = 7.202366
# Valid RMSE in = 8.259055
# Test RMSE in 2018= 4.540134
# 2
# Train RMSE in = 7.147512
# Valid RMSE in = 8.179498
# Test RMSE in 2018= 4.583424
# 3
# Train RMSE in = 7.236978
# Valid RMSE in = 8.034545
# Test RMSE in 2018= 4.538188
# 4
# Train RMSE in = 7.218704
# Valid RMSE in = 8.157803
# Test RMSE in 2018= 4.529901
# 2019
# 0
# Train RMSE in = 7.096029
# Valid RMSE in = 7.837031
# Test RMSE in 2019= 7.578564
# 1
# Train RMSE in = 7.076242
# Valid RMSE in = 8.088187
# Test RMSE in 2019= 7.522137
# 2
# Train RMSE in = 7.073105
# Valid RMSE in = 8.058157
# Test RMSE in 2019= 7.554028
# 3
# Train RMSE in = 7.077224
# Valid RMSE in = 7.927766
# Test RMSE in 2019= 7.580363
# 4
# Train RMSE in = 7.053311
# Valid RMSE in = 8.02982
# Test RMSE in 2019= 7.553451
# 2020
# 0
# Train RMSE in = 7.040689
# Valid RMSE in = 7.845547
# Test RMSE in 2020= 7.137021
# 1
# Train RMSE in = 7.073595
# Valid RMSE in = 8.14199
# Test RMSE in 2020= 7.170604
# 2
# Train RMSE in = 7.039556
# Valid RMSE in = 8.099166
# Test RMSE in 2020= 7.139687
# 3
# Train RMSE in = 7.082594
# Valid RMSE in = 7.908914
# Test RMSE in 2020= 7.198761
# 4
# Train RMSE in = 7.057721
# Valid RMSE in = 8.059891
# Test RMSE in 2020= 7.05827
# Sim_Clim+LU+Def
# 2003
# 0
# Train RMSE in = 5.553255
# Valid RMSE in = 6.677741
# Test RMSE in 2003= 8.243722
# 1
# Train RMSE in = 5.558355
# Valid RMSE in = 6.853317
# Test RMSE in 2003= 8.180745
# 2
# Train RMSE in = 5.488658
# Valid RMSE in = 7.05856
# Test RMSE in 2003= 8.171837
# 3
# Train RMSE in = 5.547421
# Valid RMSE in = 6.851153
# Test RMSE in 2003= 8.249547
# 4
# Train RMSE in = 5.584646
# Valid RMSE in = 6.411211
# Test RMSE in 2003= 8.18595
# 2004
# 0
# Train RMSE in = 5.461037
# Valid RMSE in = 6.543812
# Test RMSE in 2004= 9.458496
# 1
# Train RMSE in = 5.501953
# Valid RMSE in = 6.718041
# Test RMSE in 2004= 9.404782
# 2
# Train RMSE in = 5.402194
# Valid RMSE in = 6.997073
# Test RMSE in 2004= 9.41012
# 3
# Train RMSE in = 5.432352
# Valid RMSE in = 6.76384
# Test RMSE in 2004= 9.360332
# 4
# Train RMSE in = 5.503028
# Valid RMSE in = 6.449377
# Test RMSE in 2004= 9.529405
# 2005
# 0
# Train RMSE in = 5.403322
# Valid RMSE in = 6.427503
# Test RMSE in 2005= 11.121728
# 1
# Train RMSE in = 5.396313
# Valid RMSE in = 6.602055
# Test RMSE in 2005= 11.10674
# 2
# Train RMSE in = 5.261132
# Valid RMSE in = 6.898904
# Test RMSE in 2005= 11.199623
# 3
# Train RMSE in = 5.392634
# Valid RMSE in = 6.584784
# Test RMSE in 2005= 11.117556
# 4
# Train RMSE in = 5.39927
# Valid RMSE in = 6.271856
# Test RMSE in 2005= 11.168882
# 2006
# 0
# Train RMSE in = 5.618115
# Valid RMSE in = 6.794393
# Test RMSE in 2006= 7.328763
# 1
# Train RMSE in = 5.629004
# Valid RMSE in = 6.904215
# Test RMSE in 2006= 7.201616
# 2
# Train RMSE in = 5.548982
# Valid RMSE in = 7.03296
# Test RMSE in 2006= 7.219241
# 3
# Train RMSE in = 5.61176
# Valid RMSE in = 6.836608
# Test RMSE in 2006= 7.311653
# 4
# Train RMSE in = 5.608496
# Valid RMSE in = 6.538962
# Test RMSE in 2006= 7.236028
# 2007
# 0
# Train RMSE in = 5.447602
# Valid RMSE in = 6.560689
# Test RMSE in 2007= 11.198546
# 1
# Train RMSE in = 5.403148
# Valid RMSE in = 6.676729
# Test RMSE in 2007= 11.238904
# 2
# Train RMSE in = 5.371294
# Valid RMSE in = 6.666183
# Test RMSE in 2007= 11.168494
# 3
# Train RMSE in = 5.415764
# Valid RMSE in = 6.619211
# Test RMSE in 2007= 11.272146
# 4
# Train RMSE in = 5.445731
# Valid RMSE in = 6.301315
# Test RMSE in 2007= 11.232875
# 2008
# 0
# Train RMSE in = 5.621749
# Valid RMSE in = 6.97174
# Test RMSE in 2008= 6.215166
# 1
# Train RMSE in = 5.71815
# Valid RMSE in = 7.066914
# Test RMSE in 2008= 6.242088
# 2
# Train RMSE in = 5.633512
# Valid RMSE in = 6.918661
# Test RMSE in 2008= 6.19839
# 3
# Train RMSE in = 5.659203
# Valid RMSE in = 6.906007
# Test RMSE in 2008= 6.223371
# 4
# Train RMSE in = 5.637611
# Valid RMSE in = 6.681476
# Test RMSE in 2008= 6.234965
# 2009
# 0
# Train RMSE in = 5.726564
# Valid RMSE in = 6.991366
# Test RMSE in 2009= 4.747251
# 1
# Train RMSE in = 5.724801
# Valid RMSE in = 7.087047
# Test RMSE in 2009= 4.790672
# 2
# Train RMSE in = 5.671521
# Valid RMSE in = 6.998045
# Test RMSE in 2009= 4.815512
# 3
# Train RMSE in = 5.710503
# Valid RMSE in = 7.031762
# Test RMSE in 2009= 4.821408
# 4
# Train RMSE in = 5.738437
# Valid RMSE in = 6.697272
# Test RMSE in 2009= 4.897513
# 2010
# 0
# Train RMSE in = 5.398679
# Valid RMSE in = 6.585931
# Test RMSE in 2010= 11.615983
# 1
# Train RMSE in = 5.425599
# Valid RMSE in = 6.424888
# Test RMSE in 2010= 11.697064
# 2
# Train RMSE in = 5.397902
# Valid RMSE in = 6.449809
# Test RMSE in 2010= 11.718555
# 3
# Train RMSE in = 5.402517
# Valid RMSE in = 6.580501
# Test RMSE in 2010= 11.716977
# 4
# Train RMSE in = 5.41238
# Valid RMSE in = 6.493572
# Test RMSE in 2010= 11.608392
# 2011
# 0
# Train RMSE in = 5.726907
# Valid RMSE in = 6.972062
# Test RMSE in 2011= 3.56574
# 1
# Train RMSE in = 5.753443
# Valid RMSE in = 7.018883
# Test RMSE in 2011= 3.618406
# 2
# Train RMSE in = 5.736436
# Valid RMSE in = 7.046701
# Test RMSE in 2011= 3.651072
# 3
# Train RMSE in = 5.763731
# Valid RMSE in = 6.922666
# Test RMSE in 2011= 3.593102
# 4
# Train RMSE in = 5.74426
# Valid RMSE in = 7.088115
# Test RMSE in 2011= 3.596519
# 2012
# 0
# Train RMSE in = 5.693477
# Valid RMSE in = 6.972628
# Test RMSE in 2012= 4.96152
# 1
# Train RMSE in = 5.715264
# Valid RMSE in = 6.991866
# Test RMSE in 2012= 5.005154
# 2
# Train RMSE in = 5.701855
# Valid RMSE in = 6.967873
# Test RMSE in 2012= 5.012124
# 3
# Train RMSE in = 5.720701
# Valid RMSE in = 6.853831
# Test RMSE in 2012= 5.002052
# 4
# Train RMSE in = 5.657553
# Valid RMSE in = 7.029176
# Test RMSE in 2012= 4.987466
# 2013
# 0
# Train RMSE in = 5.764852
# Valid RMSE in = 6.980916
# Test RMSE in 2013= 2.7378
# 1
# Train RMSE in = 5.825469
# Valid RMSE in = 7.07389
# Test RMSE in 2013= 2.713345
# 2
# Train RMSE in = 5.768033
# Valid RMSE in = 7.063484
# Test RMSE in 2013= 2.695811
# 3
# Train RMSE in = 5.782431
# Valid RMSE in = 6.981885
# Test RMSE in 2013= 2.721519
# 4
# Train RMSE in = 5.787327
# Valid RMSE in = 7.089371
# Test RMSE in 2013= 2.757024
# 2014
# 0
# Train RMSE in = 5.753671
# Valid RMSE in = 6.968895
# Test RMSE in 2014= 4.21718
# 1
# Train RMSE in = 5.758556
# Valid RMSE in = 7.031165
# Test RMSE in 2014= 4.227292
# 2
# Train RMSE in = 5.708398
# Valid RMSE in = 7.050945
# Test RMSE in 2014= 4.23196
# 3
# Train RMSE in = 5.779015
# Valid RMSE in = 6.901597
# Test RMSE in 2014= 4.2117
# 4
# Train RMSE in = 5.713543
# Valid RMSE in = 7.078481
# Test RMSE in 2014= 4.186243
# 2015
# 0
# Train RMSE in = 5.691016
# Valid RMSE in = 6.873552
# Test RMSE in 2015= 5.716893
# 1
# Train RMSE in = 5.686308
# Valid RMSE in = 6.972637
# Test RMSE in 2015= 5.725197
# 2
# Train RMSE in = 5.623982
# Valid RMSE in = 6.988399
# Test RMSE in 2015= 5.751292
# 3
# Train RMSE in = 5.670907
# Valid RMSE in = 6.826755
# Test RMSE in 2015= 5.673701
# 4
# Train RMSE in = 5.687232
# Valid RMSE in = 7.039563
# Test RMSE in 2015= 5.654216
# 2016
# 0
# Train RMSE in = 5.648702
# Valid RMSE in = 6.858083
# Test RMSE in 2016= 5.701774
# 1
# Train RMSE in = 5.714601
# Valid RMSE in = 6.981981
# Test RMSE in 2016= 6.012269
# 2
# Train RMSE in = 5.639203
# Valid RMSE in = 6.991697
# Test RMSE in 2016= 5.74687
# 3
# Train RMSE in = 5.697982
# Valid RMSE in = 6.822856
# Test RMSE in 2016= 5.808727
# 4
# Train RMSE in = 5.671136
# Valid RMSE in = 7.028224
# Test RMSE in 2016= 5.789618
# 2017
# 0
# Train RMSE in = 5.681733
# Valid RMSE in = 6.782831
# Test RMSE in 2017= 6.120155
# 1
# Train RMSE in = 5.668047
# Valid RMSE in = 6.97605
# Test RMSE in 2017= 6.081988
# 2
# Train RMSE in = 5.642463
# Valid RMSE in = 6.960772
# Test RMSE in 2017= 6.120741
# 3
# Train RMSE in = 5.642063
# Valid RMSE in = 6.820005
# Test RMSE in 2017= 6.088177
# 4
# Train RMSE in = 5.619935
# Valid RMSE in = 7.029999
# Test RMSE in 2017= 6.084872
# 2018
# 0
# Train RMSE in = 5.762234
# Valid RMSE in = 6.875251
# Test RMSE in 2018= 3.738801
# 1
# Train RMSE in = 5.753027
# Valid RMSE in = 7.079658
# Test RMSE in 2018= 3.791059
# 2
# Train RMSE in = 5.725428
# Valid RMSE in = 7.011332
# Test RMSE in 2018= 3.790441
# 3
# Train RMSE in = 5.722972
# Valid RMSE in = 6.943713
# Test RMSE in 2018= 3.809081
# 4
# Train RMSE in = 5.769993
# Valid RMSE in = 7.100568
# Test RMSE in 2018= 3.802009
# 2019
# 0
# Train RMSE in = 5.63481
# Valid RMSE in = 6.722665
# Test RMSE in 2019= 6.890564
# 1
# Train RMSE in = 5.606431
# Valid RMSE in = 6.929066
# Test RMSE in 2019= 6.881
# 2
# Train RMSE in = 5.602075
# Valid RMSE in = 6.88213
# Test RMSE in 2019= 6.900457
# 3
# Train RMSE in = 5.60202
# Valid RMSE in = 6.824421
# Test RMSE in 2019= 6.879407
# 4
# Train RMSE in = 5.631557
# Valid RMSE in = 6.964914
# Test RMSE in 2019= 6.850711
# 2020
# 0
# Train RMSE in = 5.643334
# Valid RMSE in = 6.735123
# Test RMSE in 2020= 6.214547
# 1
# Train RMSE in = 5.644786
# Valid RMSE in = 7.034458
# Test RMSE in 2020= 6.278059
# 2
# Train RMSE in = 5.635565
# Valid RMSE in = 6.953219
# Test RMSE in 2020= 6.187126
# 3
# Train RMSE in = 5.607903
# Valid RMSE in = 6.824057
# Test RMSE in 2020= 6.191375
# 4
# Train RMSE in = 5.607163
# Valid RMSE in = 7.005292
# Test RMSE in 2020= 6.168892
